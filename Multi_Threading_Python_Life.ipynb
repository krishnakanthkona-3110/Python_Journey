# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnakanthkona-3110/Python_Journey/blob/main/Multi_Threading_Python_Life.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program is a set of instructions.

# %%
# Process - The process is a program (set of instructions) in execution
# Process cannot share the memory

# %%
''' Thread:
- Thread is a light-weight processess.
- Threads can be used to perform complicated tasks in the background without interrupting
  the main program.
- Threads can share the memory.

- Threads are present in the process.
'''
# Out:
# ' Thread:\n- Thread is a light-weight processess.\n- Threads can be used to perform complicated tasks in the background without interrupting\n  the main program.\n- Threads can share the memory.\n\n- Threads are present in the process.\n'

# %%
'''
run(): is the entry point for a thread.

start(): method starts a thread by calling the run method.

join([time]): waits for threads to terminate.

is_Alive(): method checks whether a thread is still executing.

getName(): method returns the name of a thread.

'''
# Out:
# '\nrun(): is the entry point for a thread.\n\nstart(): method starts a thread by calling the run method.\n\njoin([time]): waits for threads to terminate.\n\nisAlive(): method checks whether a thread is still executing.\n\ngetName(): method returns the name of a thread.\n\n'

# %%
import threading
from threading import *
from time import sleep

# %%
class First_thread(Thread):
  def run(self):
    for i in range(1,10):
      print(i, 'This is 1st thread')
      sleep(1)

class Second_thread(Thread):
  def run(self):
    for i in range(1,10):
      print(i, 'This is 2nd thread')
      sleep(1)


t1 = First_thread()
t2 = Second_thread()

t1.start()
t2.start()
# Out:
# 1 This is 1st thread
# 1 This is 2nd thread

# %%
# Out:
# 1 This is 1st thread
# 2 This is 1st thread
# 3 This is 1st thread
# 4 This is 1st thread
# 5 This is 1st thread
# 6 This is 1st thread
# 7 This is 1st thread
# 8 This is 1st thread
# 9 This is 1st thread
# 1 This is 2nd thread
# 2 This is 2nd thread
# 3 This is 2nd thread
# 4 This is 2nd thread
# 5 This is 2nd thread
# 6 This is 2nd thread
# 7 This is 2nd thread
# 8 This is 2nd thread
# 9 This is 2nd thread

# %%
t1.run()
t2.run()
# Out:
# 1 This is 1st thread
# 2 This is 1st thread
# 3 This is 1st thread
# 4 This is 1st thread
# 5 This is 1st thread
# 6 This is 1st thread
# 7 This is 1st thread
# 8 This is 1st thread
# 9 This is 1st thread
# 1 This is 2nd thread
# 2 This is 2nd thread
# 3 This is 2nd thread
# 4 This is 2nd thread
# 5 This is 2nd thread
# 6 This is 2nd thread
# 7 This is 2nd thread
# 8 This is 2nd thread
# 9 This is 2nd thread

# %%
t1.start()
t2.start()
# Out:
# 1 This is 1st thread
# 2 This is 1st thread
# 3 This is 1st thread
# 4 This is 1st thread
# 5 This is 1st thread
# 6 This is 1st thread
# 7 This is 1st thread
# 8 This is 1st thread
# 9 This is 1st thread
# 1 This is 2nd thread
# 2 This is 2nd thread
# 3 This is 2nd thread
# 4 This is 2nd thread
# 5 This is 2nd thread
# 6 This is 2nd thread
# 7 This is 2nd thread
# 8 This is 2nd thread
# 9 This is 2nd thread

# %%
class First_thread(Thread):
  def run(self):
    for i in range(1,10):
      print(i, 'This is 1st thread')
      sleep(1)

class Second_thread(Thread):
  def run(self):
    for i in range(1,10):
      print(i, 'This is 2nd thread')
      sleep(1)

class Third_thread(Thread):
  def run(self):
    for i in range(1,10):
      print(i, 'This is 3rd thread')
      sleep(1)

t1 = First_thread()
t2 = Second_thread()
t3 = Third_thread()

t1.start()
sleep(1)
t2.start()
sleep(1)
t3.start()
sleep(1)
# Out:
# 1 This is 1st thread
# 2 This is 1st thread
# 1 This is 2nd thread
# 3 This is 1st thread
# 2 This is 2nd thread
# 1 This is 3rd thread
# 4 This is 1st thread
# 3 This is 2nd thread
# 2 This is 3rd thread

# %%
class First_thread(Thread):
  def run(self):
    for i in range(1,10):
      print(i, 'This is 1st thread')
      sleep(1)

class Second_thread(Thread):
  def run(self):
    for i in range(1,10):
      print(i, 'This is 2nd thread')
      sleep(1)


t1 = First_thread()
t2 = Second_thread()

t1.start()
print(t1.is_alive())
t2.start()
print(t2.is_alive())
t1.join()
t2.join()
print(t1.is_alive())
print(t2.is_alive())
# Out:
# 1 This is 1st thread
# True
# 1 This is 2nd thread
# True
# 2 This is 1st thread
# 2 This is 2nd thread
# 3 This is 1st thread
# 3 This is 2nd thread
# 4 This is 1st thread
# 4 This is 2nd thread
# 5 This is 1st thread
# 5 This is 2nd thread
# 6 This is 1st thread
# 6 This is 2nd thread
# 7 This is 1st thread
# 7 This is 2nd thread
# 8 This is 1st thread
# 8 This is 2nd thread
# 9 This is 1st thread
# 9 This is 2nd thread
# False
# False

# %%
import threading
print(threading.current_thread().getName())
# Out:
# MainThread
# /tmp/ipython-input-3049133128.py:2: DeprecationWarning: getName() is deprecated, get the name attribute instead
#   print(threading.current_thread().getName())

# %%
# Regex

# %%
f = 'python \n programming'
print(f)
# Out:
# python
#  programming

# %%
k = r'python \n programming'
print(k)
# Out:
# python \n programming

# %%
import re

# %%
# Regex is totally works on strings
